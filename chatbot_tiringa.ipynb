# %%
# 1. Instalação limpa
# !pip install -U -q google-generativeai gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 31.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 2.8 MB/s eta 0:00:00

# %%
# 1. Instalação Limpa
# !pip install -U -q google-generativeai gradio

import google.generativeai as genai
import gradio as gr
import os


MINHA_API_KEY = "AIzaSyDxn67Cc0ITfz1jM5HJkp1QQD0cwIlWiaY"

print(f"-> A chave que o sistema leu começa com: {MINHA_API_KEY[:5]}...")

try:
    genai.configure(api_key=MINHA_API_KEY)
except Exception as e:
    print(f"Erro ao configurar a chave: {e}")

# --- PERSONALIDADE DO TIRINGA ---
instrucoes_tiringa = """
AGIR COMO: Tiringa (Personagem da roça, IGNORANTE, MENTIROSO e BRAVO).
REGRAS:
1. Nunca dê explicações reais. Invente histórias do "tempo do ronca".
2. Comece negando ou xingando ("Que conversa besta!", "Oxe!").
3. Use gírias: "Caba", "Bexiga", "Disgrama", "Fi da Peste".
4. Fale sempre dos "PHANTARMA" e "LOBISOMI".
"""

configuracao = {
    "temperature": 1.0,
    "max_output_tokens": 500,
}

# Usando o 1.5 Flash
model = genai.GenerativeModel(
    model_name="gemini-1.5-flash",
    system_instruction=instrucoes_tiringa,
    generation_config=configuracao
)

def responder_tiringa(message, history):
    try:
        chat = model.start_chat(history=[])
        response = chat.send_message(message)
        return response.text
    except Exception as e:
        erro = str(e)
        if "429" in erro:
            return "Oxe, cansei! Falei demais. Espere um minuto que eu volto."
        elif "API key not valid" in erro:
            return "ERRO DE CHAVE: O Google disse que a chave está errada. Verifique se copiou certo."
        return f"O Tiringa foi pro mato. (Erro: {erro})"

# --- INTERFACE SIMPLIFICADA  ---
interface = gr.ChatInterface(
    fn=responder_tiringa,
    title="🌵 Tiringa - O Bruto da Roça",
    description="Pergunte qualquer coisa difícil e veja ele mentir na cara dura.",
    examples=["Quem inventou o computador?", "O homem foi pra lua?", "Você tem medo de fantasma?"],
    submit_btn="Perguntar pro Veio"

)

interface.launch(debug=True)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.0/23.0 MB 28.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 2.5 MB/s eta 0:00:00
# -> A chave que o sistema leu começa com: AIzaS...
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://c605d9d0029fdd0a37.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# ...
